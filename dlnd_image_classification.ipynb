# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile
import math

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 54
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 54:
# Image - Min Value: 9 Max Value: 227
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return (np.divide(x, 255.0))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lit = [i for i in range(10)]
    lb = LabelBinarizer()
    lb.fit(lit)
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    batch_size= [None]
    batch_size.extend(image_shape)
    return tf.placeholder(tf.float32, shape = batch_size, name = 'x')
    return None


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name='y')

def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name= 'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    print (x_tensor)
    weight= tf.Variable(tf.truncated_normal((conv_ksize[0], conv_ksize[1], int(x_tensor.get_shape().as_list()[3]), conv_num_outputs), stddev= 1.0/math.sqrt(conv_num_outputs)))
    biases= tf.Variable(tf.zeros(conv_num_outputs))
    conv2d= tf.nn.conv2d(x_tensor, weight, strides=[1, *conv_strides, 1], padding = 'SAME')
    conv2d= tf.add(conv2d, biases)
    conv2d= tf.nn.relu(conv2d)
    conv2d= tf.nn.max_pool(conv2d, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding = 'SAME' )
    return conv2d 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tensor("Placeholder:0", shape=(?, 32, 32, 5), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape= x_tensor.get_shape().as_list()
    dim= np.prod(shape[1:])
    flat_layer = tf.reshape(x_tensor, [-1, dim ])
    return flat_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.random_normal((int(x_tensor.get_shape().as_list()[1]), num_outputs), stddev=1/math.sqrt(num_outputs)))
    bias = tf.Variable(tf.zeros(num_outputs))
    result_mul = tf.add(tf.matmul(x_tensor, weight), bias)
    output = tf.nn.relu(result_mul)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print (x_tensor.get_shape().as_list()[1])
    weight = tf.Variable(tf.random_normal((x_tensor.get_shape().as_list()[1], num_outputs)))
    bias = tf.Variable(tf.zeros(num_outputs))
    result= tf.add(tf.matmul(x_tensor,weight), bias)
    return result 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# 128
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_dropout_prob = keep_prob / 2
    
    conv1 = conv2d_maxpool(x, 48,(5,5),(2, 2), (2, 2), (2, 2))
    
    
    conv2 = conv2d_maxpool(conv1, 48,(3,3),(2, 2), (2, 2), (2, 2))
    
    conv2_drop = tf.nn.dropout(conv2, conv_dropout_prob)
    
    conv3 = conv2d_maxpool(conv2_drop, 96, (5, 5), (2, 2), (2, 2), (2, 2))
    
    conv3_drop = tf.nn.dropout(conv3, conv_dropout_prob)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    flat = flatten(conv3_drop)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fconn = fully_conn(flat, 512)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 256)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    result = output(fconn_w_dropout, 10)
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("MaxPool:0", shape=(?, 8, 8, 48), dtype=float32)
# Tensor("dropout/mul:0", shape=(?, 2, 2, 48), dtype=float32)
# 256
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("MaxPool_3:0", shape=(?, 8, 8, 48), dtype=float32)
# Tensor("dropout_4/mul:0", shape=(?, 2, 2, 48), dtype=float32)
# 256
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    session.run(optimizer, feed_dict = {x: feature_batch,
                                        y: label_batch,
                                        keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict = {x: feature_batch,
                                          y: label_batch,
                                          keep_prob: 1.0})
    acc = session.run(accuracy, feed_dict = {x: valid_features,
                                             y: valid_labels,
                                             keep_prob: 1.0})
    print('Loss: {:>10.2f}, Accuracy: {:.6f}'.format(loss, acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:       2.30, Accuracy: 0.136000
# Epoch  2, CIFAR-10 Batch 1:  Loss:       2.29, Accuracy: 0.162000
# Epoch  3, CIFAR-10 Batch 1:  Loss:       2.20, Accuracy: 0.188200
# Epoch  4, CIFAR-10 Batch 1:  Loss:       2.17, Accuracy: 0.205400
# Epoch  5, CIFAR-10 Batch 1:  Loss:       2.24, Accuracy: 0.213400
# Epoch  6, CIFAR-10 Batch 1:  Loss:       2.17, Accuracy: 0.233800
# Epoch  7, CIFAR-10 Batch 1:  Loss:       2.11, Accuracy: 0.257000
# Epoch  8, CIFAR-10 Batch 1:  Loss:       2.09, Accuracy: 0.262400
# Epoch  9, CIFAR-10 Batch 1:  Loss:       2.05, Accuracy: 0.260600
# Epoch 10, CIFAR-10 Batch 1:  Loss:       2.12, Accuracy: 0.268400
# Epoch 11, CIFAR-10 Batch 1:  Loss:       2.10, Accuracy: 0.282200
# Epoch 12, CIFAR-10 Batch 1:  Loss:       2.15, Accuracy: 0.284600
# Epoch 13, CIFAR-10 Batch 1:  Loss:       2.11, Accuracy: 0.298400
# Epoch 14, CIFAR-10 Batch 1:  Loss:       2.14, Accuracy: 0.290000
# Epoch 15, CIFAR-10 Batch 1:  Loss:       2.00, Accuracy: 0.307400
# Epoch 16, CIFAR-10 Batch 1:  Loss:       1.94, Accuracy: 0.314400
# Epoch 17, CIFAR-10 Batch 1:  Loss:       1.85, Accuracy: 0.310200
# Epoch 18, CIFAR-10 Batch 1:  Loss:       1.96, Accuracy: 0.312400
# Epoch 19, CIFAR-10 Batch 1:  Loss:       1.90, Accuracy: 0.328000
# Epoch 20, CIFAR-10 Batch 1:  Loss:       2.03, Accuracy: 0.320400
# Epoch 21, CIFAR-10 Batch 1:  Loss:       1.95, Accuracy: 0.343800
# Epoch 22, CIFAR-10 Batch 1:  Loss:       1.90, Accuracy: 0.337400
# Epoch 23, CIFAR-10 Batch 1:  Loss:       1.82, Accuracy: 0.344800
# Epoch 24, CIFAR-10 Batch 1:  Loss:       1.90, Accuracy: 0.333000
# Epoch 25, CIFAR-10 Batch 1:  Loss:       2.00, Accuracy: 0.349000
# Epoch 26, CIFAR-10 Batch 1:  Loss:       1.93, Accuracy: 0.348200
# Epoch 27, CIFAR-10 Batch 1:  Loss:       1.93, Accuracy: 0.342600
# Epoch 28, CIFAR-10 Batch 1:  Loss:       1.76, Accuracy: 0.359600
# Epoch 29, CIFAR-10 Batch 1:  Loss:       1.90, Accuracy: 0.363000
# Epoch 30, CIFAR-10 Batch 1:  Loss:       1.74, Accuracy: 0.368400
# Epoch 31, CIFAR-10 Batch 1:  Loss:       1.72, Accuracy: 0.362000
# Epoch 32, CIFAR-10 Batch 1:  Loss:       1.74, Accuracy: 0.375800
# Epoch 33, CIFAR-10 Batch 1:  Loss:       1.62, Accuracy: 0.368000
# Epoch 34, CIFAR-10 Batch 1:  Loss:       1.90, Accuracy: 0.368000
# Epoch 35, CIFAR-10 Batch 1:  Loss:       1.63, Accuracy: 0.361800
# Epoch 36, CIFAR-10 Batch 1:  Loss:       1.75, Accuracy: 0.370800
# Epoch 37, CIFAR-10 Batch 1:  Loss:       1.70, Accuracy: 0.371000
# Epoch 38, CIFAR-10 Batch 1:  Loss:       1.60, Accuracy: 0.378400
# Epoch 39, CIFAR-10 Batch 1:  Loss:       1.57, Accuracy: 0.377000
# Epoch 40, CIFAR-10 Batch 1:  Loss:       1.74, Accuracy: 0.385800
# Epoch 41, CIFAR-10 Batch 1:  Loss:       1.66, Accuracy: 0.387800
# Epoch 42, CIFAR-10 Batch 1:  Loss:       1.50, Accuracy: 0.389400
# Epoch 43, CIFAR-10 Batch 1:  Loss:       1.65, Accuracy: 0.373000
# Epoch 44, CIFAR-10 Batch 1:  Loss:       1.57, Accuracy: 0.391000
# Epoch 45, CIFAR-10 Batch 1:  Loss:       1.74, Accuracy: 0.369400
# Epoch 46, CIFAR-10 Batch 1:  Loss:       1.62, Accuracy: 0.392800
# Epoch 47, CIFAR-10 Batch 1:  Loss:       1.63, Accuracy: 0.390400
# Epoch 48, CIFAR-10 Batch 1:  Loss:       1.37, Accuracy: 0.394800
# Epoch 49, CIFAR-10 Batch 1:  Loss:       1.46, Accuracy: 0.386800
# Epoch 50, CIFAR-10 Batch 1:  Loss:       1.56, Accuracy: 0.397000
# Epoch 51, CIFAR-10 Batch 1:  Loss:       1.53, Accuracy: 0.394600
# Epoch 52, CIFAR-10 Batch 1:  Loss:       1.64, Accuracy: 0.388800
# Epoch 53, CIFAR-10 Batch 1:  Loss:       1.53, Accuracy: 0.391800
# Epoch 54, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.390600
# Epoch 55, CIFAR-10 Batch 1:  Loss:       1.63, Accuracy: 0.393600
# Epoch 56, CIFAR-10 Batch 1:  Loss:       1.50, Accuracy: 0.410200
# Epoch 57, CIFAR-10 Batch 1:  Loss:       1.41, Accuracy: 0.400600
# Epoch 58, CIFAR-10 Batch 1:  Loss:       1.51, Accuracy: 0.394800
# Epoch 59, CIFAR-10 Batch 1:  Loss:       1.52, Accuracy: 0.389800
# Epoch 60, CIFAR-10 Batch 1:  Loss:       1.31, Accuracy: 0.408600
# Epoch 61, CIFAR-10 Batch 1:  Loss:       1.38, Accuracy: 0.406200
# Epoch 62, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.401800
# Epoch 63, CIFAR-10 Batch 1:  Loss:       1.43, Accuracy: 0.412600
# Epoch 64, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.410600
# Epoch 65, CIFAR-10 Batch 1:  Loss:       1.29, Accuracy: 0.400600
# Epoch 66, CIFAR-10 Batch 1:  Loss:       1.26, Accuracy: 0.409200
# Epoch 67, CIFAR-10 Batch 1:  Loss:       1.25, Accuracy: 0.399600
# Epoch 68, CIFAR-10 Batch 1:  Loss:       1.48, Accuracy: 0.408800
# Epoch 69, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.411200
# Epoch 70, CIFAR-10 Batch 1:  Loss:       1.29, Accuracy: 0.412800
# Epoch 71, CIFAR-10 Batch 1:  Loss:       1.39, Accuracy: 0.420000
# Epoch 72, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.410000
# Epoch 73, CIFAR-10 Batch 1:  Loss:       1.37, Accuracy: 0.418000
# Epoch 74, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.413400
# Epoch 75, CIFAR-10 Batch 1:  Loss:       1.29, Accuracy: 0.410400
# Epoch 76, CIFAR-10 Batch 1:  Loss:       1.40, Accuracy: 0.417400
# Epoch 77, CIFAR-10 Batch 1:  Loss:       1.39, Accuracy: 0.402800
# Epoch 78, CIFAR-10 Batch 1:  Loss:       1.44, Accuracy: 0.415600
# Epoch 79, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.414400
# Epoch 80, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.421000
# Epoch 81, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.416400
# Epoch 82, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.414200
# Epoch 83, CIFAR-10 Batch 1:  Loss:       1.10, Accuracy: 0.424000
# Epoch 84, CIFAR-10 Batch 1:  Loss:       1.14, Accuracy: 0.408400
# Epoch 85, CIFAR-10 Batch 1:  Loss:       1.30, Accuracy: 0.421800
# Epoch 86, CIFAR-10 Batch 1:  Loss:       1.25, Accuracy: 0.419600
# Epoch 87, CIFAR-10 Batch 1:  Loss:       1.18, Accuracy: 0.417800
# Epoch 88, CIFAR-10 Batch 1:  Loss:       1.35, Accuracy: 0.419800
# Epoch 89, CIFAR-10 Batch 1:  Loss:       1.08, Accuracy: 0.428200
# Epoch 90, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.432600
# Epoch 91, CIFAR-10 Batch 1:  Loss:       1.09, Accuracy: 0.429400
# Epoch 92, CIFAR-10 Batch 1:  Loss:       1.13, Accuracy: 0.430800
# Epoch 93, CIFAR-10 Batch 1:  Loss:       1.02, Accuracy: 0.428000
# Epoch 94, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.433200
# Epoch 95, CIFAR-10 Batch 1:  Loss:       1.15, Accuracy: 0.433400
# Epoch 96, CIFAR-10 Batch 1:  Loss:       1.11, Accuracy: 0.437600
# Epoch 97, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.431400
# Epoch 98, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.418400
# Epoch 99, CIFAR-10 Batch 1:  Loss:       1.14, Accuracy: 0.414200
# Epoch 100, CIFAR-10 Batch 1:  Loss:       1.30, Accuracy: 0.430000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:       2.29, Accuracy: 0.125400
# Epoch  1, CIFAR-10 Batch 2:  Loss:       2.29, Accuracy: 0.138000
# Epoch  1, CIFAR-10 Batch 3:  Loss:       2.18, Accuracy: 0.150600
# Epoch  1, CIFAR-10 Batch 4:  Loss:       2.09, Accuracy: 0.189600
# Epoch  1, CIFAR-10 Batch 5:  Loss:       2.11, Accuracy: 0.204600
# Epoch  2, CIFAR-10 Batch 1:  Loss:       2.26, Accuracy: 0.220800
# Epoch  2, CIFAR-10 Batch 2:  Loss:       1.99, Accuracy: 0.227400
# Epoch  2, CIFAR-10 Batch 3:  Loss:       1.92, Accuracy: 0.218200
# Epoch  2, CIFAR-10 Batch 4:  Loss:       1.99, Accuracy: 0.259000
# Epoch  2, CIFAR-10 Batch 5:  Loss:       2.03, Accuracy: 0.246600
# Epoch  3, CIFAR-10 Batch 1:  Loss:       2.20, Accuracy: 0.255800
# Epoch  3, CIFAR-10 Batch 2:  Loss:       1.91, Accuracy: 0.272200
# Epoch  3, CIFAR-10 Batch 3:  Loss:       1.78, Accuracy: 0.262200
# Epoch  3, CIFAR-10 Batch 4:  Loss:       1.83, Accuracy: 0.274200
# Epoch  3, CIFAR-10 Batch 5:  Loss:       1.82, Accuracy: 0.280800
# Epoch  4, CIFAR-10 Batch 1:  Loss:       2.05, Accuracy: 0.287800
# Epoch  4, CIFAR-10 Batch 2:  Loss:       1.96, Accuracy: 0.290000
# Epoch  4, CIFAR-10 Batch 3:  Loss:       1.69, Accuracy: 0.288600
# Epoch  4, CIFAR-10 Batch 4:  Loss:       1.79, Accuracy: 0.300800
# Epoch  4, CIFAR-10 Batch 5:  Loss:       1.77, Accuracy: 0.300200
# Epoch  5, CIFAR-10 Batch 1:  Loss:       1.99, Accuracy: 0.329600
# Epoch  5, CIFAR-10 Batch 2:  Loss:       1.83, Accuracy: 0.317200
# Epoch  5, CIFAR-10 Batch 3:  Loss:       1.63, Accuracy: 0.327200
# Epoch  5, CIFAR-10 Batch 4:  Loss:       1.80, Accuracy: 0.329000
# Epoch  5, CIFAR-10 Batch 5:  Loss:       1.83, Accuracy: 0.318600
# Epoch  6, CIFAR-10 Batch 1:  Loss:       1.87, Accuracy: 0.343600
# Epoch  6, CIFAR-10 Batch 2:  Loss:       1.70, Accuracy: 0.330200
# Epoch  6, CIFAR-10 Batch 3:  Loss:       1.57, Accuracy: 0.326600
# Epoch  6, CIFAR-10 Batch 4:  Loss:       1.74, Accuracy: 0.356000
# Epoch  6, CIFAR-10 Batch 5:  Loss:       1.60, Accuracy: 0.336400
# Epoch  7, CIFAR-10 Batch 1:  Loss:       1.82, Accuracy: 0.354600
# Epoch  7, CIFAR-10 Batch 2:  Loss:       1.73, Accuracy: 0.340400
# Epoch  7, CIFAR-10 Batch 3:  Loss:       1.62, Accuracy: 0.350400
# Epoch  7, CIFAR-10 Batch 4:  Loss:       1.68, Accuracy: 0.357200
# Epoch  7, CIFAR-10 Batch 5:  Loss:       1.69, Accuracy: 0.357200
# Epoch  8, CIFAR-10 Batch 1:  Loss:       1.87, Accuracy: 0.369800
# Epoch  8, CIFAR-10 Batch 2:  Loss:       1.64, Accuracy: 0.363000
# Epoch  8, CIFAR-10 Batch 3:  Loss:       1.55, Accuracy: 0.356800
# Epoch  8, CIFAR-10 Batch 4:  Loss:       1.64, Accuracy: 0.357000
# Epoch  8, CIFAR-10 Batch 5:  Loss:       1.56, Accuracy: 0.368200
# Epoch  9, CIFAR-10 Batch 1:  Loss:       1.91, Accuracy: 0.385000
# Epoch  9, CIFAR-10 Batch 2:  Loss:       1.65, Accuracy: 0.385200
# Epoch  9, CIFAR-10 Batch 3:  Loss:       1.44, Accuracy: 0.360800
# Epoch  9, CIFAR-10 Batch 4:  Loss:       1.72, Accuracy: 0.378600
# Epoch  9, CIFAR-10 Batch 5:  Loss:       1.51, Accuracy: 0.366600
# Epoch 10, CIFAR-10 Batch 1:  Loss:       1.77, Accuracy: 0.386600
# Epoch 10, CIFAR-10 Batch 2:  Loss:       1.67, Accuracy: 0.381800
# Epoch 10, CIFAR-10 Batch 3:  Loss:       1.37, Accuracy: 0.381200
# Epoch 10, CIFAR-10 Batch 4:  Loss:       1.67, Accuracy: 0.391400
# Epoch 10, CIFAR-10 Batch 5:  Loss:       1.59, Accuracy: 0.386200
# Epoch 11, CIFAR-10 Batch 1:  Loss:       1.76, Accuracy: 0.389000
# Epoch 11, CIFAR-10 Batch 2:  Loss:       1.54, Accuracy: 0.385000
# Epoch 11, CIFAR-10 Batch 3:  Loss:       1.40, Accuracy: 0.377200
# Epoch 11, CIFAR-10 Batch 4:  Loss:       1.57, Accuracy: 0.393800
# Epoch 11, CIFAR-10 Batch 5:  Loss:       1.52, Accuracy: 0.387800
# Epoch 12, CIFAR-10 Batch 1:  Loss:       1.60, Accuracy: 0.396600
# Epoch 12, CIFAR-10 Batch 2:  Loss:       1.62, Accuracy: 0.392400
# Epoch 12, CIFAR-10 Batch 3:  Loss:       1.33, Accuracy: 0.406800
# Epoch 12, CIFAR-10 Batch 4:  Loss:       1.50, Accuracy: 0.394200
# Epoch 12, CIFAR-10 Batch 5:  Loss:       1.54, Accuracy: 0.391200
# Epoch 13, CIFAR-10 Batch 1:  Loss:       1.78, Accuracy: 0.410000
# Epoch 13, CIFAR-10 Batch 2:  Loss:       1.61, Accuracy: 0.393800
# Epoch 13, CIFAR-10 Batch 3:  Loss:       1.42, Accuracy: 0.393400
# Epoch 13, CIFAR-10 Batch 4:  Loss:       1.53, Accuracy: 0.411600
# Epoch 13, CIFAR-10 Batch 5:  Loss:       1.44, Accuracy: 0.411000
# Epoch 14, CIFAR-10 Batch 1:  Loss:       1.51, Accuracy: 0.419800
# Epoch 14, CIFAR-10 Batch 2:  Loss:       1.67, Accuracy: 0.412400
# Epoch 14, CIFAR-10 Batch 3:  Loss:       1.41, Accuracy: 0.404600
# Epoch 14, CIFAR-10 Batch 4:  Loss:       1.47, Accuracy: 0.399400
# Epoch 14, CIFAR-10 Batch 5:  Loss:       1.48, Accuracy: 0.414000
# Epoch 15, CIFAR-10 Batch 1:  Loss:       1.67, Accuracy: 0.410400
# Epoch 15, CIFAR-10 Batch 2:  Loss:       1.72, Accuracy: 0.417200
# Epoch 15, CIFAR-10 Batch 3:  Loss:       1.31, Accuracy: 0.413200
# Epoch 15, CIFAR-10 Batch 4:  Loss:       1.41, Accuracy: 0.422400
# Epoch 15, CIFAR-10 Batch 5:  Loss:       1.56, Accuracy: 0.402800
# Epoch 16, CIFAR-10 Batch 1:  Loss:       1.66, Accuracy: 0.425000
# Epoch 16, CIFAR-10 Batch 2:  Loss:       1.63, Accuracy: 0.427400
# Epoch 16, CIFAR-10 Batch 3:  Loss:       1.33, Accuracy: 0.417200
# Epoch 16, CIFAR-10 Batch 4:  Loss:       1.48, Accuracy: 0.421800
# Epoch 16, CIFAR-10 Batch 5:  Loss:       1.44, Accuracy: 0.425000
# Epoch 17, CIFAR-10 Batch 1:  Loss:       1.70, Accuracy: 0.432000
# Epoch 17, CIFAR-10 Batch 2:  Loss:       1.59, Accuracy: 0.431200
# Epoch 17, CIFAR-10 Batch 3:  Loss:       1.27, Accuracy: 0.421800
# Epoch 17, CIFAR-10 Batch 4:  Loss:       1.44, Accuracy: 0.422400
# Epoch 17, CIFAR-10 Batch 5:  Loss:       1.42, Accuracy: 0.425200
# Epoch 18, CIFAR-10 Batch 1:  Loss:       1.53, Accuracy: 0.427600
# Epoch 18, CIFAR-10 Batch 2:  Loss:       1.63, Accuracy: 0.421800
# Epoch 18, CIFAR-10 Batch 3:  Loss:       1.27, Accuracy: 0.428200
# Epoch 18, CIFAR-10 Batch 4:  Loss:       1.46, Accuracy: 0.418600
# Epoch 18, CIFAR-10 Batch 5:  Loss:       1.39, Accuracy: 0.416200
# Epoch 19, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.439400
# Epoch 19, CIFAR-10 Batch 2:  Loss:       1.58, Accuracy: 0.436800
# Epoch 19, CIFAR-10 Batch 3:  Loss:       1.38, Accuracy: 0.423200
# Epoch 19, CIFAR-10 Batch 4:  Loss:       1.50, Accuracy: 0.431000
# Epoch 19, CIFAR-10 Batch 5:  Loss:       1.40, Accuracy: 0.436000
# Epoch 20, CIFAR-10 Batch 1:  Loss:       1.55, Accuracy: 0.431800
# Epoch 20, CIFAR-10 Batch 2:  Loss:       1.46, Accuracy: 0.440600
# Epoch 20, CIFAR-10 Batch 3:  Loss:       1.34, Accuracy: 0.434000
# Epoch 20, CIFAR-10 Batch 4:  Loss:       1.42, Accuracy: 0.449200
# Epoch 20, CIFAR-10 Batch 5:  Loss:       1.40, Accuracy: 0.427000
# Epoch 21, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.438800
# Epoch 21, CIFAR-10 Batch 2:  Loss:       1.44, Accuracy: 0.438000
# Epoch 21, CIFAR-10 Batch 3:  Loss:       1.27, Accuracy: 0.428800
# Epoch 21, CIFAR-10 Batch 4:  Loss:       1.40, Accuracy: 0.450400
# Epoch 21, CIFAR-10 Batch 5:  Loss:       1.41, Accuracy: 0.442000
# Epoch 22, CIFAR-10 Batch 1:  Loss:       1.48, Accuracy: 0.444000
# Epoch 22, CIFAR-10 Batch 2:  Loss:       1.34, Accuracy: 0.446800
# Epoch 22, CIFAR-10 Batch 3:  Loss:       1.23, Accuracy: 0.444800
# Epoch 22, CIFAR-10 Batch 4:  Loss:       1.49, Accuracy: 0.446200
# Epoch 22, CIFAR-10 Batch 5:  Loss:       1.33, Accuracy: 0.446800
# Epoch 23, CIFAR-10 Batch 1:  Loss:       1.42, Accuracy: 0.453600
# Epoch 23, CIFAR-10 Batch 2:  Loss:       1.51, Accuracy: 0.444600
# Epoch 23, CIFAR-10 Batch 3:  Loss:       1.26, Accuracy: 0.441400
# Epoch 23, CIFAR-10 Batch 4:  Loss:       1.30, Accuracy: 0.454200
# Epoch 23, CIFAR-10 Batch 5:  Loss:       1.34, Accuracy: 0.452000
# Epoch 24, CIFAR-10 Batch 1:  Loss:       1.46, Accuracy: 0.463200
# Epoch 24, CIFAR-10 Batch 2:  Loss:       1.63, Accuracy: 0.460600
# Epoch 24, CIFAR-10 Batch 3:  Loss:       1.33, Accuracy: 0.453800
# Epoch 24, CIFAR-10 Batch 4:  Loss:       1.36, Accuracy: 0.455800
# Epoch 24, CIFAR-10 Batch 5:  Loss:       1.38, Accuracy: 0.430400
# Epoch 25, CIFAR-10 Batch 1:  Loss:       1.59, Accuracy: 0.457400
# Epoch 25, CIFAR-10 Batch 2:  Loss:       1.45, Accuracy: 0.462800
# Epoch 25, CIFAR-10 Batch 3:  Loss:       1.27, Accuracy: 0.446200
# Epoch 25, CIFAR-10 Batch 4:  Loss:       1.45, Accuracy: 0.441200
# Epoch 25, CIFAR-10 Batch 5:  Loss:       1.36, Accuracy: 0.460800
# Epoch 26, CIFAR-10 Batch 1:  Loss:       1.50, Accuracy: 0.461000
# Epoch 26, CIFAR-10 Batch 2:  Loss:       1.51, Accuracy: 0.462400
# Epoch 26, CIFAR-10 Batch 3:  Loss:       1.26, Accuracy: 0.444800
# Epoch 26, CIFAR-10 Batch 4:  Loss:       1.33, Accuracy: 0.459800
# Epoch 26, CIFAR-10 Batch 5:  Loss:       1.52, Accuracy: 0.447200
# Epoch 27, CIFAR-10 Batch 1:  Loss:       1.45, Accuracy: 0.468000
# Epoch 27, CIFAR-10 Batch 2:  Loss:       1.37, Accuracy: 0.471800
# Epoch 27, CIFAR-10 Batch 3:  Loss:       1.17, Accuracy: 0.467400
# Epoch 27, CIFAR-10 Batch 4:  Loss:       1.39, Accuracy: 0.467400
# Epoch 27, CIFAR-10 Batch 5:  Loss:       1.28, Accuracy: 0.468800
# Epoch 28, CIFAR-10 Batch 1:  Loss:       1.59, Accuracy: 0.472000
# Epoch 28, CIFAR-10 Batch 2:  Loss:       1.38, Accuracy: 0.467600
# Epoch 28, CIFAR-10 Batch 3:  Loss:       1.27, Accuracy: 0.467000
# Epoch 28, CIFAR-10 Batch 4:  Loss:       1.44, Accuracy: 0.463000
# Epoch 28, CIFAR-10 Batch 5:  Loss:       1.24, Accuracy: 0.465200
# Epoch 29, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.477200
# Epoch 29, CIFAR-10 Batch 2:  Loss:       1.28, Accuracy: 0.473600
# Epoch 29, CIFAR-10 Batch 3:  Loss:       1.25, Accuracy: 0.480200
# Epoch 29, CIFAR-10 Batch 4:  Loss:       1.40, Accuracy: 0.457400
# Epoch 29, CIFAR-10 Batch 5:  Loss:       1.30, Accuracy: 0.465000
# Epoch 30, CIFAR-10 Batch 1:  Loss:       1.53, Accuracy: 0.460000
# Epoch 30, CIFAR-10 Batch 2:  Loss:       1.36, Accuracy: 0.468000
# Epoch 30, CIFAR-10 Batch 3:  Loss:       1.32, Accuracy: 0.475600
# Epoch 30, CIFAR-10 Batch 4:  Loss:       1.29, Accuracy: 0.467800
# Epoch 30, CIFAR-10 Batch 5:  Loss:       1.30, Accuracy: 0.477400
# Epoch 31, CIFAR-10 Batch 1:  Loss:       1.50, Accuracy: 0.463800
# Epoch 31, CIFAR-10 Batch 2:  Loss:       1.38, Accuracy: 0.471200
# Epoch 31, CIFAR-10 Batch 3:  Loss:       1.22, Accuracy: 0.473400
# Epoch 31, CIFAR-10 Batch 4:  Loss:       1.30, Accuracy: 0.476000
# Epoch 31, CIFAR-10 Batch 5:  Loss:       1.32, Accuracy: 0.478000
# Epoch 32, CIFAR-10 Batch 1:  Loss:       1.45, Accuracy: 0.485000
# Epoch 32, CIFAR-10 Batch 2:  Loss:       1.28, Accuracy: 0.480000
# Epoch 32, CIFAR-10 Batch 3:  Loss:       1.26, Accuracy: 0.478400
# Epoch 32, CIFAR-10 Batch 4:  Loss:       1.34, Accuracy: 0.466200
# Epoch 32, CIFAR-10 Batch 5:  Loss:       1.28, Accuracy: 0.472600
# Epoch 33, CIFAR-10 Batch 1:  Loss:       1.37, Accuracy: 0.473400
# Epoch 33, CIFAR-10 Batch 2:  Loss:       1.39, Accuracy: 0.481000
# Epoch 33, CIFAR-10 Batch 3:  Loss:       1.13, Accuracy: 0.476200
# Epoch 33, CIFAR-10 Batch 4:  Loss:       1.41, Accuracy: 0.472800
# Epoch 33, CIFAR-10 Batch 5:  Loss:       1.37, Accuracy: 0.482600
# Epoch 34, CIFAR-10 Batch 1:  Loss:       1.50, Accuracy: 0.463200
# Epoch 34, CIFAR-10 Batch 2:  Loss:       1.31, Accuracy: 0.489600
# Epoch 34, CIFAR-10 Batch 3:  Loss:       1.17, Accuracy: 0.480000
# Epoch 34, CIFAR-10 Batch 4:  Loss:       1.31, Accuracy: 0.486400
# Epoch 34, CIFAR-10 Batch 5:  Loss:       1.32, Accuracy: 0.473600
# Epoch 35, CIFAR-10 Batch 1:  Loss:       1.37, Accuracy: 0.485400
# Epoch 35, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.482800
# Epoch 35, CIFAR-10 Batch 3:  Loss:       1.22, Accuracy: 0.467600
# Epoch 35, CIFAR-10 Batch 4:  Loss:       1.23, Accuracy: 0.491000
# Epoch 35, CIFAR-10 Batch 5:  Loss:       1.24, Accuracy: 0.479600
# Epoch 36, CIFAR-10 Batch 1:  Loss:       1.49, Accuracy: 0.492600
# Epoch 36, CIFAR-10 Batch 2:  Loss:       1.34, Accuracy: 0.492400
# Epoch 36, CIFAR-10 Batch 3:  Loss:       1.14, Accuracy: 0.485600
# Epoch 36, CIFAR-10 Batch 4:  Loss:       1.40, Accuracy: 0.476800
# Epoch 36, CIFAR-10 Batch 5:  Loss:       1.36, Accuracy: 0.485200
# Epoch 37, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.488800
# Epoch 37, CIFAR-10 Batch 2:  Loss:       1.32, Accuracy: 0.477400
# Epoch 37, CIFAR-10 Batch 3:  Loss:       1.38, Accuracy: 0.484400
# Epoch 37, CIFAR-10 Batch 4:  Loss:       1.22, Accuracy: 0.475200
# Epoch 37, CIFAR-10 Batch 5:  Loss:       1.23, Accuracy: 0.491400
# Epoch 38, CIFAR-10 Batch 1:  Loss:       1.29, Accuracy: 0.487200
# Epoch 38, CIFAR-10 Batch 2:  Loss:       1.30, Accuracy: 0.484600
# Epoch 38, CIFAR-10 Batch 3:  Loss:       1.11, Accuracy: 0.483400
# Epoch 38, CIFAR-10 Batch 4:  Loss:       1.22, Accuracy: 0.482200
# Epoch 38, CIFAR-10 Batch 5:  Loss:       1.21, Accuracy: 0.493400
# Epoch 39, CIFAR-10 Batch 1:  Loss:       1.43, Accuracy: 0.494800
# Epoch 39, CIFAR-10 Batch 2:  Loss:       1.42, Accuracy: 0.481800
# Epoch 39, CIFAR-10 Batch 3:  Loss:       1.12, Accuracy: 0.485400
# Epoch 39, CIFAR-10 Batch 4:  Loss:       1.31, Accuracy: 0.495600
# Epoch 39, CIFAR-10 Batch 5:  Loss:       1.23, Accuracy: 0.484200
# Epoch 40, CIFAR-10 Batch 1:  Loss:       1.40, Accuracy: 0.490800
# Epoch 40, CIFAR-10 Batch 2:  Loss:       1.28, Accuracy: 0.497200
# Epoch 40, CIFAR-10 Batch 3:  Loss:       1.11, Accuracy: 0.469000
# Epoch 40, CIFAR-10 Batch 4:  Loss:       1.34, Accuracy: 0.490000
# Epoch 40, CIFAR-10 Batch 5:  Loss:       1.27, Accuracy: 0.482200
# Epoch 41, CIFAR-10 Batch 1:  Loss:       1.38, Accuracy: 0.483600
# Epoch 41, CIFAR-10 Batch 2:  Loss:       1.27, Accuracy: 0.497400
# Epoch 41, CIFAR-10 Batch 3:  Loss:       1.14, Accuracy: 0.467800
# Epoch 41, CIFAR-10 Batch 4:  Loss:       1.23, Accuracy: 0.499400
# Epoch 41, CIFAR-10 Batch 5:  Loss:       1.20, Accuracy: 0.485000
# Epoch 42, CIFAR-10 Batch 1:  Loss:       1.30, Accuracy: 0.496400
# Epoch 42, CIFAR-10 Batch 2:  Loss:       1.41, Accuracy: 0.498200
# Epoch 42, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.490000
# Epoch 42, CIFAR-10 Batch 4:  Loss:       1.28, Accuracy: 0.488200
# Epoch 42, CIFAR-10 Batch 5:  Loss:       1.36, Accuracy: 0.480200
# Epoch 43, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.489200
# Epoch 43, CIFAR-10 Batch 2:  Loss:       1.22, Accuracy: 0.487600
# Epoch 43, CIFAR-10 Batch 3:  Loss:       1.05, Accuracy: 0.494400
# Epoch 43, CIFAR-10 Batch 4:  Loss:       1.27, Accuracy: 0.497800
# Epoch 43, CIFAR-10 Batch 5:  Loss:       1.31, Accuracy: 0.495400
# Epoch 44, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.503000
# Epoch 44, CIFAR-10 Batch 2:  Loss:       1.31, Accuracy: 0.505800
# Epoch 44, CIFAR-10 Batch 3:  Loss:       1.11, Accuracy: 0.486600
# Epoch 44, CIFAR-10 Batch 4:  Loss:       1.42, Accuracy: 0.501200
# Epoch 44, CIFAR-10 Batch 5:  Loss:       1.30, Accuracy: 0.489800
# Epoch 45, CIFAR-10 Batch 1:  Loss:       1.35, Accuracy: 0.496800
# Epoch 45, CIFAR-10 Batch 2:  Loss:       1.34, Accuracy: 0.502600
# Epoch 45, CIFAR-10 Batch 3:  Loss:       1.21, Accuracy: 0.499600
# Epoch 45, CIFAR-10 Batch 4:  Loss:       1.21, Accuracy: 0.489000
# Epoch 45, CIFAR-10 Batch 5:  Loss:       1.26, Accuracy: 0.495000
# Epoch 46, CIFAR-10 Batch 1:  Loss:       1.30, Accuracy: 0.474200
# Epoch 46, CIFAR-10 Batch 2:  Loss:       1.30, Accuracy: 0.498800
# Epoch 46, CIFAR-10 Batch 3:  Loss:       1.20, Accuracy: 0.491200
# Epoch 46, CIFAR-10 Batch 4:  Loss:       1.30, Accuracy: 0.498600
# Epoch 46, CIFAR-10 Batch 5:  Loss:       1.34, Accuracy: 0.489800
# Epoch 47, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.506000
# Epoch 47, CIFAR-10 Batch 2:  Loss:       1.24, Accuracy: 0.494400
# Epoch 47, CIFAR-10 Batch 3:  Loss:       1.16, Accuracy: 0.491400
# Epoch 47, CIFAR-10 Batch 4:  Loss:       1.29, Accuracy: 0.502200
# Epoch 47, CIFAR-10 Batch 5:  Loss:       1.08, Accuracy: 0.489800
# Epoch 48, CIFAR-10 Batch 1:  Loss:       1.24, Accuracy: 0.503800
# Epoch 48, CIFAR-10 Batch 2:  Loss:       1.26, Accuracy: 0.498200
# Epoch 48, CIFAR-10 Batch 3:  Loss:       1.17, Accuracy: 0.491800
# Epoch 48, CIFAR-10 Batch 4:  Loss:       1.24, Accuracy: 0.499800
# Epoch 48, CIFAR-10 Batch 5:  Loss:       1.30, Accuracy: 0.504800
# Epoch 49, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.493000
# Epoch 49, CIFAR-10 Batch 2:  Loss:       1.31, Accuracy: 0.517400
# Epoch 49, CIFAR-10 Batch 3:  Loss:       1.12, Accuracy: 0.513200
# Epoch 49, CIFAR-10 Batch 4:  Loss:       1.10, Accuracy: 0.505800
# Epoch 49, CIFAR-10 Batch 5:  Loss:       1.07, Accuracy: 0.490200
# Epoch 50, CIFAR-10 Batch 1:  Loss:       1.36, Accuracy: 0.500200
# Epoch 50, CIFAR-10 Batch 2:  Loss:       1.24, Accuracy: 0.503000
# Epoch 50, CIFAR-10 Batch 3:  Loss:       1.08, Accuracy: 0.498600
# Epoch 50, CIFAR-10 Batch 4:  Loss:       1.24, Accuracy: 0.501200
# Epoch 50, CIFAR-10 Batch 5:  Loss:       1.24, Accuracy: 0.500200
# Epoch 51, CIFAR-10 Batch 1:  Loss:       1.24, Accuracy: 0.506000
# Epoch 51, CIFAR-10 Batch 2:  Loss:       1.32, Accuracy: 0.500200
# Epoch 51, CIFAR-10 Batch 3:  Loss:       1.13, Accuracy: 0.502600
# Epoch 51, CIFAR-10 Batch 4:  Loss:       1.10, Accuracy: 0.493400
# Epoch 51, CIFAR-10 Batch 5:  Loss:       1.08, Accuracy: 0.499400
# Epoch 52, CIFAR-10 Batch 1:  Loss:       1.25, Accuracy: 0.506600
# Epoch 52, CIFAR-10 Batch 2:  Loss:       1.12, Accuracy: 0.508600
# Epoch 52, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.496600
# Epoch 52, CIFAR-10 Batch 4:  Loss:       1.13, Accuracy: 0.495200
# Epoch 52, CIFAR-10 Batch 5:  Loss:       1.14, Accuracy: 0.506400
# Epoch 53, CIFAR-10 Batch 1:  Loss:       1.26, Accuracy: 0.513000
# Epoch 53, CIFAR-10 Batch 2:  Loss:       1.19, Accuracy: 0.514000
# Epoch 53, CIFAR-10 Batch 3:  Loss:       1.08, Accuracy: 0.519400
# Epoch 53, CIFAR-10 Batch 4:  Loss:       1.16, Accuracy: 0.503200
# Epoch 53, CIFAR-10 Batch 5:  Loss:       1.12, Accuracy: 0.506200
# Epoch 54, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.509400
# Epoch 54, CIFAR-10 Batch 2:  Loss:       1.35, Accuracy: 0.501000
# Epoch 54, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.504400
# Epoch 54, CIFAR-10 Batch 4:  Loss:       1.21, Accuracy: 0.517200
# Epoch 54, CIFAR-10 Batch 5:  Loss:       1.14, Accuracy: 0.505200
# Epoch 55, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.516800
# Epoch 55, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.511200
# Epoch 55, CIFAR-10 Batch 3:  Loss:       0.98, Accuracy: 0.506200
# Epoch 55, CIFAR-10 Batch 4:  Loss:       1.11, Accuracy: 0.513000
# Epoch 55, CIFAR-10 Batch 5:  Loss:       1.07, Accuracy: 0.500600
# Epoch 56, CIFAR-10 Batch 1:  Loss:       1.26, Accuracy: 0.510600
# Epoch 56, CIFAR-10 Batch 2:  Loss:       1.13, Accuracy: 0.511600
# Epoch 56, CIFAR-10 Batch 3:  Loss:       0.96, Accuracy: 0.501000
# Epoch 56, CIFAR-10 Batch 4:  Loss:       1.18, Accuracy: 0.509200
# Epoch 56, CIFAR-10 Batch 5:  Loss:       1.14, Accuracy: 0.507600
# Epoch 57, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.508600
# Epoch 57, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.517800
# Epoch 57, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.514600
# Epoch 57, CIFAR-10 Batch 4:  Loss:       1.04, Accuracy: 0.515400
# Epoch 57, CIFAR-10 Batch 5:  Loss:       1.15, Accuracy: 0.514000
# Epoch 58, CIFAR-10 Batch 1:  Loss:       1.21, Accuracy: 0.509800
# Epoch 58, CIFAR-10 Batch 2:  Loss:       1.33, Accuracy: 0.497400
# Epoch 58, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.517400
# Epoch 58, CIFAR-10 Batch 4:  Loss:       1.21, Accuracy: 0.497400
# Epoch 58, CIFAR-10 Batch 5:  Loss:       1.00, Accuracy: 0.508200
# Epoch 59, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.506800
# Epoch 59, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.507400
# Epoch 59, CIFAR-10 Batch 3:  Loss:       1.01, Accuracy: 0.511600
# Epoch 59, CIFAR-10 Batch 4:  Loss:       1.21, Accuracy: 0.522800
# Epoch 59, CIFAR-10 Batch 5:  Loss:       1.21, Accuracy: 0.500200
# Epoch 60, CIFAR-10 Batch 1:  Loss:       1.24, Accuracy: 0.510200
# Epoch 60, CIFAR-10 Batch 2:  Loss:       1.05, Accuracy: 0.502000
# Epoch 60, CIFAR-10 Batch 3:  Loss:       1.02, Accuracy: 0.514200
# Epoch 60, CIFAR-10 Batch 4:  Loss:       1.13, Accuracy: 0.507400
# Epoch 60, CIFAR-10 Batch 5:  Loss:       1.21, Accuracy: 0.523000
# Epoch 61, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.502600
# Epoch 61, CIFAR-10 Batch 2:  Loss:       1.29, Accuracy: 0.507800
# Epoch 61, CIFAR-10 Batch 3:  Loss:       1.00, Accuracy: 0.524600
# Epoch 61, CIFAR-10 Batch 4:  Loss:       1.17, Accuracy: 0.518000
# Epoch 61, CIFAR-10 Batch 5:  Loss:       1.12, Accuracy: 0.500200
# Epoch 62, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.504200
# Epoch 62, CIFAR-10 Batch 2:  Loss:       1.18, Accuracy: 0.526800
# Epoch 62, CIFAR-10 Batch 3:  Loss:       0.98, Accuracy: 0.516800
# Epoch 62, CIFAR-10 Batch 4:  Loss:       1.09, Accuracy: 0.517600
# Epoch 62, CIFAR-10 Batch 5:  Loss:       1.15, Accuracy: 0.516600
# Epoch 63, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.521000
# Epoch 63, CIFAR-10 Batch 2:  Loss:       1.09, Accuracy: 0.519000
# Epoch 63, CIFAR-10 Batch 3:  Loss:       1.08, Accuracy: 0.514400
# Epoch 63, CIFAR-10 Batch 4:  Loss:       1.36, Accuracy: 0.513400
# Epoch 63, CIFAR-10 Batch 5:  Loss:       1.19, Accuracy: 0.513600
# Epoch 64, CIFAR-10 Batch 1:  Loss:       1.22, Accuracy: 0.515000
# Epoch 64, CIFAR-10 Batch 2:  Loss:       1.19, Accuracy: 0.517800
# Epoch 64, CIFAR-10 Batch 3:  Loss:       1.03, Accuracy: 0.505000
# Epoch 64, CIFAR-10 Batch 4:  Loss:       1.23, Accuracy: 0.516600
# Epoch 64, CIFAR-10 Batch 5:  Loss:       1.15, Accuracy: 0.513800
# Epoch 65, CIFAR-10 Batch 1:  Loss:       1.24, Accuracy: 0.513600
# Epoch 65, CIFAR-10 Batch 2:  Loss:       1.20, Accuracy: 0.510400
# Epoch 65, CIFAR-10 Batch 3:  Loss:       0.96, Accuracy: 0.508600
# Epoch 65, CIFAR-10 Batch 4:  Loss:       1.12, Accuracy: 0.505200
# Epoch 65, CIFAR-10 Batch 5:  Loss:       1.17, Accuracy: 0.511400
# Epoch 66, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.518000
# Epoch 66, CIFAR-10 Batch 2:  Loss:       1.13, Accuracy: 0.522200
# Epoch 66, CIFAR-10 Batch 3:  Loss:       0.95, Accuracy: 0.512800
# Epoch 66, CIFAR-10 Batch 4:  Loss:       1.13, Accuracy: 0.518000
# Epoch 66, CIFAR-10 Batch 5:  Loss:       1.10, Accuracy: 0.522000
# Epoch 67, CIFAR-10 Batch 1:  Loss:       1.12, Accuracy: 0.502000
# Epoch 67, CIFAR-10 Batch 2:  Loss:       1.19, Accuracy: 0.514400
# Epoch 67, CIFAR-10 Batch 3:  Loss:       1.01, Accuracy: 0.513000
# Epoch 67, CIFAR-10 Batch 4:  Loss:       1.12, Accuracy: 0.521400
# Epoch 67, CIFAR-10 Batch 5:  Loss:       1.15, Accuracy: 0.508600
# Epoch 68, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.505600
# Epoch 68, CIFAR-10 Batch 2:  Loss:       1.25, Accuracy: 0.510800
# Epoch 68, CIFAR-10 Batch 3:  Loss:       0.95, Accuracy: 0.514000
# Epoch 68, CIFAR-10 Batch 4:  Loss:       1.06, Accuracy: 0.524800
# Epoch 68, CIFAR-10 Batch 5:  Loss:       1.12, Accuracy: 0.512600
# Epoch 69, CIFAR-10 Batch 1:  Loss:       1.14, Accuracy: 0.509800
# Epoch 69, CIFAR-10 Batch 2:  Loss:       1.04, Accuracy: 0.520200
# Epoch 69, CIFAR-10 Batch 3:  Loss:       1.10, Accuracy: 0.515600
# Epoch 69, CIFAR-10 Batch 4:  Loss:       1.14, Accuracy: 0.524800
# Epoch 69, CIFAR-10 Batch 5:  Loss:       1.14, Accuracy: 0.513400
# Epoch 70, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.507600
# Epoch 70, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.520200
# Epoch 70, CIFAR-10 Batch 3:  Loss:       1.13, Accuracy: 0.523200
# Epoch 70, CIFAR-10 Batch 4:  Loss:       1.21, Accuracy: 0.510200
# Epoch 70, CIFAR-10 Batch 5:  Loss:       1.14, Accuracy: 0.517000
# Epoch 71, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.528200
# Epoch 71, CIFAR-10 Batch 2:  Loss:       1.08, Accuracy: 0.521000
# Epoch 71, CIFAR-10 Batch 3:  Loss:       1.03, Accuracy: 0.524400
# Epoch 71, CIFAR-10 Batch 4:  Loss:       1.17, Accuracy: 0.512600
# Epoch 71, CIFAR-10 Batch 5:  Loss:       1.15, Accuracy: 0.517600
# Epoch 72, CIFAR-10 Batch 1:  Loss:       1.06, Accuracy: 0.518400
# Epoch 72, CIFAR-10 Batch 2:  Loss:       1.10, Accuracy: 0.525600
# Epoch 72, CIFAR-10 Batch 3:  Loss:       0.99, Accuracy: 0.518000
# Epoch 72, CIFAR-10 Batch 4:  Loss:       1.07, Accuracy: 0.520400
# Epoch 72, CIFAR-10 Batch 5:  Loss:       1.28, Accuracy: 0.518600
# Epoch 73, CIFAR-10 Batch 1:  Loss:       1.13, Accuracy: 0.516200
# Epoch 73, CIFAR-10 Batch 2:  Loss:       1.20, Accuracy: 0.519600
# Epoch 73, CIFAR-10 Batch 3:  Loss:       1.00, Accuracy: 0.522000
# Epoch 73, CIFAR-10 Batch 4:  Loss:       1.15, Accuracy: 0.512600
# Epoch 73, CIFAR-10 Batch 5:  Loss:       1.11, Accuracy: 0.519200
# Epoch 74, CIFAR-10 Batch 1:  Loss:       1.13, Accuracy: 0.525800
# Epoch 74, CIFAR-10 Batch 2:  Loss:       1.21, Accuracy: 0.526000
# Epoch 74, CIFAR-10 Batch 3:  Loss:       1.01, Accuracy: 0.518400
# Epoch 74, CIFAR-10 Batch 4:  Loss:       1.10, Accuracy: 0.534600
# Epoch 74, CIFAR-10 Batch 5:  Loss:       1.09, Accuracy: 0.530000
# Epoch 75, CIFAR-10 Batch 1:  Loss:       1.23, Accuracy: 0.520800
# Epoch 75, CIFAR-10 Batch 2:  Loss:       1.18, Accuracy: 0.527800
# Epoch 75, CIFAR-10 Batch 3:  Loss:       0.90, Accuracy: 0.534600
# Epoch 75, CIFAR-10 Batch 4:  Loss:       1.16, Accuracy: 0.520800
# Epoch 75, CIFAR-10 Batch 5:  Loss:       1.10, Accuracy: 0.522000
# Epoch 76, CIFAR-10 Batch 1:  Loss:       1.07, Accuracy: 0.523600
# Epoch 76, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.503400
# Epoch 76, CIFAR-10 Batch 3:  Loss:       0.98, Accuracy: 0.521600
# Epoch 76, CIFAR-10 Batch 4:  Loss:       1.11, Accuracy: 0.531200
# Epoch 76, CIFAR-10 Batch 5:  Loss:       1.19, Accuracy: 0.525800
# Epoch 77, CIFAR-10 Batch 1:  Loss:       1.18, Accuracy: 0.518200
# Epoch 77, CIFAR-10 Batch 2:  Loss:       1.07, Accuracy: 0.521600
# Epoch 77, CIFAR-10 Batch 3:  Loss:       1.03, Accuracy: 0.524800
# Epoch 77, CIFAR-10 Batch 4:  Loss:       1.11, Accuracy: 0.523200
# Epoch 77, CIFAR-10 Batch 5:  Loss:       1.21, Accuracy: 0.523600
# Epoch 78, CIFAR-10 Batch 1:  Loss:       1.28, Accuracy: 0.526400
# Epoch 78, CIFAR-10 Batch 2:  Loss:       1.26, Accuracy: 0.524600
# Epoch 78, CIFAR-10 Batch 3:  Loss:       1.03, Accuracy: 0.514400
# Epoch 78, CIFAR-10 Batch 4:  Loss:       1.14, Accuracy: 0.528800
# Epoch 78, CIFAR-10 Batch 5:  Loss:       1.10, Accuracy: 0.518800
# Epoch 79, CIFAR-10 Batch 1:  Loss:       1.02, Accuracy: 0.525800
# Epoch 79, CIFAR-10 Batch 2:  Loss:       1.32, Accuracy: 0.533200
# Epoch 79, CIFAR-10 Batch 3:  Loss:       0.93, Accuracy: 0.519400
# Epoch 79, CIFAR-10 Batch 4:  Loss:       1.14, Accuracy: 0.525200
# Epoch 79, CIFAR-10 Batch 5:  Loss:       1.05, Accuracy: 0.524000
# Epoch 80, CIFAR-10 Batch 1:  Loss:       1.03, Accuracy: 0.523000
# Epoch 80, CIFAR-10 Batch 2:  Loss:       1.10, Accuracy: 0.502800
# Epoch 80, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.533800
# Epoch 80, CIFAR-10 Batch 4:  Loss:       1.06, Accuracy: 0.531200
# Epoch 80, CIFAR-10 Batch 5:  Loss:       1.22, Accuracy: 0.540000
# Epoch 81, CIFAR-10 Batch 1:  Loss:       1.09, Accuracy: 0.525200
# Epoch 81, CIFAR-10 Batch 2:  Loss:       1.12, Accuracy: 0.521200
# Epoch 81, CIFAR-10 Batch 3:  Loss:       0.98, Accuracy: 0.537600
# Epoch 81, CIFAR-10 Batch 4:  Loss:       1.18, Accuracy: 0.512000
# Epoch 81, CIFAR-10 Batch 5:  Loss:       1.08, Accuracy: 0.527400
# Epoch 82, CIFAR-10 Batch 1:  Loss:       1.11, Accuracy: 0.518400
# Epoch 82, CIFAR-10 Batch 2:  Loss:       1.13, Accuracy: 0.520600
# Epoch 82, CIFAR-10 Batch 3:  Loss:       1.02, Accuracy: 0.515000
# Epoch 82, CIFAR-10 Batch 4:  Loss:       1.18, Accuracy: 0.532800
# Epoch 82, CIFAR-10 Batch 5:  Loss:       1.19, Accuracy: 0.518000
# Epoch 83, CIFAR-10 Batch 1:  Loss:       1.19, Accuracy: 0.517600
# Epoch 83, CIFAR-10 Batch 2:  Loss:       1.07, Accuracy: 0.520000
# Epoch 83, CIFAR-10 Batch 3:  Loss:       0.96, Accuracy: 0.519400
# Epoch 83, CIFAR-10 Batch 4:  Loss:       1.00, Accuracy: 0.526600
# Epoch 83, CIFAR-10 Batch 5:  Loss:       1.09, Accuracy: 0.529800
# Epoch 84, CIFAR-10 Batch 1:  Loss:       1.30, Accuracy: 0.529200
# Epoch 84, CIFAR-10 Batch 2:  Loss:       1.05, Accuracy: 0.533400
# Epoch 84, CIFAR-10 Batch 3:  Loss:       1.09, Accuracy: 0.532600
# Epoch 84, CIFAR-10 Batch 4:  Loss:       1.09, Accuracy: 0.532600
# Epoch 84, CIFAR-10 Batch 5:  Loss:       1.12, Accuracy: 0.522400
# Epoch 85, CIFAR-10 Batch 1:  Loss:       1.18, Accuracy: 0.517000
# Epoch 85, CIFAR-10 Batch 2:  Loss:       1.14, Accuracy: 0.521400
# Epoch 85, CIFAR-10 Batch 3:  Loss:       1.07, Accuracy: 0.522000
# Epoch 85, CIFAR-10 Batch 4:  Loss:       1.16, Accuracy: 0.519800
# Epoch 85, CIFAR-10 Batch 5:  Loss:       1.10, Accuracy: 0.522200
# Epoch 86, CIFAR-10 Batch 1:  Loss:       1.12, Accuracy: 0.525600
# Epoch 86, CIFAR-10 Batch 2:  Loss:       1.09, Accuracy: 0.540600
# Epoch 86, CIFAR-10 Batch 3:  Loss:       0.97, Accuracy: 0.536200
# Epoch 86, CIFAR-10 Batch 4:  Loss:       0.95, Accuracy: 0.534400
# Epoch 86, CIFAR-10 Batch 5:  Loss:       1.09, Accuracy: 0.514600
# Epoch 87, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.517400
# Epoch 87, CIFAR-10 Batch 2:  Loss:       1.06, Accuracy: 0.527200
# Epoch 87, CIFAR-10 Batch 3:  Loss:       0.94, Accuracy: 0.536600
# Epoch 87, CIFAR-10 Batch 4:  Loss:       1.23, Accuracy: 0.530400
# Epoch 87, CIFAR-10 Batch 5:  Loss:       1.20, Accuracy: 0.531800
# Epoch 88, CIFAR-10 Batch 1:  Loss:       1.20, Accuracy: 0.525000
# Epoch 88, CIFAR-10 Batch 2:  Loss:       1.09, Accuracy: 0.518800
# Epoch 88, CIFAR-10 Batch 3:  Loss:       0.91, Accuracy: 0.527000
# Epoch 88, CIFAR-10 Batch 4:  Loss:       1.13, Accuracy: 0.530000
# Epoch 88, CIFAR-10 Batch 5:  Loss:       1.13, Accuracy: 0.519800
# Epoch 89, CIFAR-10 Batch 1:  Loss:       1.15, Accuracy: 0.533200
# Epoch 89, CIFAR-10 Batch 2:  Loss:       1.10, Accuracy: 0.533600
# Epoch 89, CIFAR-10 Batch 3:  Loss:       1.06, Accuracy: 0.536000
# Epoch 89, CIFAR-10 Batch 4:  Loss:       1.17, Accuracy: 0.531200
# Epoch 89, CIFAR-10 Batch 5:  Loss:       1.13, Accuracy: 0.534600
# Epoch 90, CIFAR-10 Batch 1:  Loss:       1.15, Accuracy: 0.531200
# Epoch 90, CIFAR-10 Batch 2:  Loss:       1.02, Accuracy: 0.525800
# Epoch 90, CIFAR-10 Batch 3:  Loss:       0.99, Accuracy: 0.522600
# Epoch 90, CIFAR-10 Batch 4:  Loss:       1.12, Accuracy: 0.542200
# Epoch 90, CIFAR-10 Batch 5:  Loss:       1.18, Accuracy: 0.519600
# Epoch 91, CIFAR-10 Batch 1:  Loss:       1.11, Accuracy: 0.520200
# Epoch 91, CIFAR-10 Batch 2:  Loss:       1.24, Accuracy: 0.536000
# Epoch 91, CIFAR-10 Batch 3:  Loss:       0.93, Accuracy: 0.538000
# Epoch 91, CIFAR-10 Batch 4:  Loss:       1.02, Accuracy: 0.530600
# Epoch 91, CIFAR-10 Batch 5:  Loss:       1.01, Accuracy: 0.534000
# Epoch 92, CIFAR-10 Batch 1:  Loss:       1.04, Accuracy: 0.526800
# Epoch 92, CIFAR-10 Batch 2:  Loss:       1.32, Accuracy: 0.531600
# Epoch 92, CIFAR-10 Batch 3:  Loss:       1.09, Accuracy: 0.520800
# Epoch 92, CIFAR-10 Batch 4:  Loss:       1.03, Accuracy: 0.531600
# Epoch 92, CIFAR-10 Batch 5:  Loss:       1.09, Accuracy: 0.536200
# Epoch 93, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.523200
# Epoch 93, CIFAR-10 Batch 2:  Loss:       1.23, Accuracy: 0.532600
# Epoch 93, CIFAR-10 Batch 3:  Loss:       1.04, Accuracy: 0.531400
# Epoch 93, CIFAR-10 Batch 4:  Loss:       1.17, Accuracy: 0.529000
# Epoch 93, CIFAR-10 Batch 5:  Loss:       1.05, Accuracy: 0.533800
# Epoch 94, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.537200
# Epoch 94, CIFAR-10 Batch 2:  Loss:       1.04, Accuracy: 0.534200
# Epoch 94, CIFAR-10 Batch 3:  Loss:       0.99, Accuracy: 0.533200
# Epoch 94, CIFAR-10 Batch 4:  Loss:       1.10, Accuracy: 0.522000
# Epoch 94, CIFAR-10 Batch 5:  Loss:       1.21, Accuracy: 0.528000
# Epoch 95, CIFAR-10 Batch 1:  Loss:       1.29, Accuracy: 0.539000
# Epoch 95, CIFAR-10 Batch 2:  Loss:       1.17, Accuracy: 0.537600
# Epoch 95, CIFAR-10 Batch 3:  Loss:       1.03, Accuracy: 0.535000
# Epoch 95, CIFAR-10 Batch 4:  Loss:       1.15, Accuracy: 0.535200
# Epoch 95, CIFAR-10 Batch 5:  Loss:       1.11, Accuracy: 0.529000
# Epoch 96, CIFAR-10 Batch 1:  Loss:       1.17, Accuracy: 0.537600
# Epoch 96, CIFAR-10 Batch 2:  Loss:       1.12, Accuracy: 0.521000
# Epoch 96, CIFAR-10 Batch 3:  Loss:       0.93, Accuracy: 0.530400
# Epoch 96, CIFAR-10 Batch 4:  Loss:       1.06, Accuracy: 0.521200
# Epoch 96, CIFAR-10 Batch 5:  Loss:       1.09, Accuracy: 0.537200
# Epoch 97, CIFAR-10 Batch 1:  Loss:       1.10, Accuracy: 0.535000
# Epoch 97, CIFAR-10 Batch 2:  Loss:       1.11, Accuracy: 0.540600
# Epoch 97, CIFAR-10 Batch 3:  Loss:       1.07, Accuracy: 0.527400
# Epoch 97, CIFAR-10 Batch 4:  Loss:       1.15, Accuracy: 0.540000
# Epoch 97, CIFAR-10 Batch 5:  Loss:       1.13, Accuracy: 0.539400
# Epoch 98, CIFAR-10 Batch 1:  Loss:       1.03, Accuracy: 0.537000
# Epoch 98, CIFAR-10 Batch 2:  Loss:       1.19, Accuracy: 0.525400
# Epoch 98, CIFAR-10 Batch 3:  Loss:       0.88, Accuracy: 0.538800
# Epoch 98, CIFAR-10 Batch 4:  Loss:       0.96, Accuracy: 0.545400
# Epoch 98, CIFAR-10 Batch 5:  Loss:       1.05, Accuracy: 0.533800
# Epoch 99, CIFAR-10 Batch 1:  Loss:       1.16, Accuracy: 0.532000
# Epoch 99, CIFAR-10 Batch 2:  Loss:       1.12, Accuracy: 0.530200
# Epoch 99, CIFAR-10 Batch 3:  Loss:       0.97, Accuracy: 0.538800
# Epoch 99, CIFAR-10 Batch 4:  Loss:       1.01, Accuracy: 0.528800
# Epoch 99, CIFAR-10 Batch 5:  Loss:       1.17, Accuracy: 0.550400
# Epoch 100, CIFAR-10 Batch 1:  Loss:       1.18, Accuracy: 0.538400
# Epoch 100, CIFAR-10 Batch 2:  Loss:       0.98, Accuracy: 0.540400
# Epoch 100, CIFAR-10 Batch 3:  Loss:       0.98, Accuracy: 0.537600
# Epoch 100, CIFAR-10 Batch 4:  Loss:       1.11, Accuracy: 0.519600
# Epoch 100, CIFAR-10 Batch 5:  Loss:       1.02, Accuracy: 0.539200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5444026898734177

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
